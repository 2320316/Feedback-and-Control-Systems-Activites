# %%
# !pip3 install openai keyboard langchain langchain-community
# Out:
# Requirement already satisfied: openai in ./.venv/lib/python3.14/site-packages (2.30.0)
# Requirement already satisfied: keyboard in ./.venv/lib/python3.14/site-packages (0.13.5)
# Requirement already satisfied: langchain in ./.venv/lib/python3.14/site-packages (1.2.13)
# Requirement already satisfied: langchain-community in ./.venv/lib/python3.14/site-packages (0.4.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.14/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.14/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.14/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.14/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.14/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.14/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.14/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./.venv/lib/python3.14/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: pyobjc in ./.venv/lib/python3.14/site-packages (from keyboard) (12.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in ./.venv/lib/python3.14/site-packages (from langchain) (1.2.22)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in ./.venv/lib/python3.14/site-packages (from langchain) (1.1.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./.venv/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in ./.venv/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.14/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./.venv/lib/python3.14/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./.venv/lib/python3.14/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in ./.venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./.venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: pyobjc-core==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-libxpc==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AdServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ARKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AVKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Accounts==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Automator==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-BrowserEngineKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CallKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Carbon==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CompositorServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Contacts==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreData==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreML==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreText==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DeviceDiscoveryExtension==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-EventKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-FSKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-GameController==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-GameSave==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Intents==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MailKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MapKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MediaExtension==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Metal==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-NetFS==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Network==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-OSLog==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-PassKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-PHASE==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Photos==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-PushKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Quartz==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Security==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SecurityUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Social==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Speech==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-WebKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-GameKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Symbols==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-Vision==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==12.1 in ./.venv/lib/python3.14/site-packages (from pyobjc->keyboard) (12.1)

# %%
from openai import OpenAI

# Connect to LM Studio local server
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"  # any string works
)

# %%
import keyboard
from langchain_community.chat_message_histories import ChatMessageHistory

# Initialize the history object to keep track of the discussion
history = ChatMessageHistory()

# %%
while True:
    query = input("\nUser (Enter to Continue || Type 'exit' or press ESC to exit): ")

    # Check for the ESC character (\x1b) OR a simple 'exit' command
    if keyboard.is_pressed('Esc') or query.lower() == 'exit':
        print("\nExiting...")
        print("Program Finished.")
        break
    print("User Input: " + query)
    print('- ' * 50)
    if not query.strip():
        continue
    # Add user message to LangChain history
    history.add_user_message(query)

    # Convert LangChain 'human/ai' roles to OpenAI 'user/assistant' roles
    messages_with_history = []
    for m in history.messages:
        # LangChain uses 'human' for user and 'ai' for assistant
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({"role": role, "content": m.content})

    # Ensured stream is called only once with the correctly mapped history
    stream = client.chat.completions.create(
        model="mistralai/ministral-3-14b-reasoning",
        messages=messages_with_history,
        stream=True
    )
    full_ai_response = ""       # Temporary variable to capture the full AI response for memory

    for chunk in stream:
        if chunk.choices[0].delta.content:
            content = chunk.choices[0].delta.content
            print(content, end="", flush=True)
            full_ai_response += content     # Build the string as it streams

    # Save the AI response back to LangChain history
    history.add_ai_message(full_ai_response)
    print('\n ')     # Print a newline for readability
    print('=' * 100)
    print(' ')
# Out:
# User Input: my name is marc aaron africano
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Hello, Marc Aaron Africano! Welcome—it's nice to have you here. What can I do for you today?
#
# ====================================================================================================
#
# User Input: as a local llm what can you do
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Hi Marc Aaron Africano! As your local LLM, I’m here to assist you in a variety of ways. Here’s what I can do for you:
#
# - **Answer Questions**: Whether it’s about science, history, technology, or general knowledge, I can provide detailed and accurate responses based on my training data (up to 2023).
# - **Language Processing**: Need help with writing, editing, or translating? I can generate human-like text, summarize long documents, or even assist with creative writing like stories or poems.
# - **Technical Assistance**: Stuck with coding or debugging? I can help with programming languages, troubleshoot issues, or explain complex technical concepts in simpler terms.
# - **Conversational Support**: I can engage in meaningful conversations, offer advice (within my knowledge limits), or just chat about topics you’re interested in.
# - **Localized Knowledge**: Depending on your region or language preferences, I might be optimized to provide more relevant or culturally adapted responses.
#
# Of course, I don’t have real-time data access beyond 2023, so for the latest news or updates, I’d recommend checking reliable sources. If you’re looking for something specific—whether it’s educational support, professional help, or just a fun chat—I’m here to assist!
#
# What would you like me to help you with today, Marc?
#
# ====================================================================================================
#
# User Input: what are the core principles of AI
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Artificial Intelligence (AI) is built on several core principles that guide its development, functionality, and ethical deployment. These principles can be categorized into foundational goals, technical approaches, and societal considerations. Here’s a breakdown:
#
# ### 1. **Fundamental Goals of AI**
#    - **Intelligence Mimicry**: AI aims to replicate human-like cognitive functions such as reasoning, problem-solving, learning, and decision-making.
#    - **Autonomy**: AI systems should operate independently in their environment, making decisions without constant human input.
#    - **Adaptability**: AI learns from data or experiences, improving its performance over time (e.g., machine learning models).
#
# ### 2. **Key Technical Principles**
#    - **Learning**:
#      - **Supervised Learning**: Learns from labeled data (e.g., image recognition).
#      - **Unsupervised Learning**: Finds patterns in unlabeled data (e.g., clustering).
#      - **Reinforcement Learning**: Learns by interacting with an environment and receiving rewards or penalties (e.g., game-playing AI like AlphaGo).
#    - **Representation**:
#      - How knowledge is stored and processed. This can be symbolic (rules/logic) or sub-symbolic (neural networks, statistical models).
#    - **Generalization**:
#      - AI should apply learned knowledge to new, unseen situations without overfitting to training data.
#    - **Robustness**:
#      - Handling noise, uncertainty, and edge cases gracefully. For example, an AI should perform well even with incomplete or corrupted data.
#
# ### 3. **Ethical and Societal Principles**
#    - **Transparency (Explainability)**:
#      - Users and stakeholders should understand how AI systems make decisions (e.g., avoiding "black box" models where decisions are opaque).
#    - **Fairness**:
#      - AI should avoid biases that lead to unfair treatment of certain groups. This involves auditing datasets and algorithms for discrimination.
#    - **Accountability**:
#      - Clear responsibility must be defined when AI systems fail or cause harm (e.g., who is liable if an autonomous car causes an accident?).
#    - **Privacy**:
#      - Respecting user data rights, especially in contexts like surveillance or personalized recommendations.
#
# ### 4. **Human-AI Collaboration**
#    - **Augmentation**:
#      - AI should assist humans rather than replace them entirely (e.g., AI tools for doctors or engineers).
#    - **User-Centric Design**:
#      - Interfaces and interactions with AI should be intuitive, accessible, and aligned with human needs.
#
# ### 5. **Technical Considerations**
#    - **Data-Driven Approach**:
#      - Most modern AI relies on vast amounts of data to train models effectively.
#    - **Efficiency and Scalability**:
#      - Balancing computational resources (e.g., memory, processing power) with performance, especially for large-scale applications like natural language processing or computer vision.
#
# ### 6. **Approaches to AI**
#    - **Symbolic AI**:
#      - Relies on logical rules and symbolic representations (e.g., expert systems in medicine).
#    - **Connectionist AI (Neural Networks/Deep Learning)**:
#      - Uses neural networks inspired by the brain, excelling at pattern recognition (e.g., image or speech processing).
#    - **Hybrid Systems**:
#      - Combines symbolic reasoning with machine learning for more robust performance.
#
# ### Why These Principles Matter
# These principles ensure that AI is not only technically sound but also ethical, fair, and beneficial to society. For example:
# - Without fairness, an AI hiring tool might inadvertently favor one demographic over another.
# - Without transparency, users may not trust AI systems (e.g., in healthcare or finance).
# - Without robustness, AI could fail spectacularly in real-world scenarios (e.g., self-driving cars in unexpected weather).
#
# Would you like me to dive deeper into any of these areas, Marc? For example, we could explore how reinforcement learning works or discuss specific ethical dilemmas in AI. Let me know what interests you!
#
# ====================================================================================================
#
# User Input: what are these ethical principles you follow and would break them so solve a dillemma
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Great question, Marc! Ethical principles in AI are the guidelines that shape responsible development and deployment. However, like any system, there are trade-offs or dilemmas where adhering strictly to one principle might conflict with another—or even require breaking it to achieve a greater good (or avoid harm). Let’s break this down:
#
# ---
#
# ### **Core Ethical Principles I Follow**
# 1. **Fairness/Equity**:
#    - *Goal*: Avoid bias and ensure fair treatment across groups.
#    - *Example*: Auditing datasets to remove racial or gender biases in hiring algorithms.
#
# 2. **Transparency (Explainability)**:
#    - *Goal*: Users should understand how decisions are made.
#    - *Example*: Providing clear explanations for loan approvals or medical diagnoses.
#
# 3. **Privacy**:
#    - *Goal*: Respect user data rights and avoid surveillance without consent.
#    - *Example*: Anonymizing personal data in research or refusing to track users without permission.
#
# 4. **Accountability**:
#    - *Goal*: Clarify responsibility when AI systems fail or cause harm.
#    - *Example*: Defining legal frameworks for autonomous vehicles (e.g., who is liable if an AI-driven car crashes?).
#
# 5. **Safety and Robustness**:
#    - *Goal*: Ensure AI systems are reliable, secure, and don’t cause unintended harm.
#    - *Example*: Testing self-driving cars extensively to avoid accidents.
#
# 6. **Human-Centric Design**:
#    - *Goal*: AI should augment human capabilities without replacing them or dehumanizing interactions.
#    - *Example*: Avoiding over-reliance on AI in jobs where human judgment is critical (e.g., therapy).
#
# 7. **Autonomy and Consent**:
#    - *Goal*: Users should have control over their data and interactions with AI.
#    - *Example*: Allowing users to opt out of personalized ads or AI-driven recommendations.
#
# ---
#
# ### **Dilemmas Where Principles Might Conflict**
# Ethical dilemmas arise when two (or more) principles clash, forcing a choice. Here are some examples:
#
# #### 1. **Privacy vs. Safety**
#    - *Scenario*: A city uses AI to predict crime hotspots using surveillance data.
#      - *Privacy*: Collecting location data without consent violates individual privacy.
#      - *Safety*: The data could prevent crimes, saving lives.
#    - *Dilemma*: Do we break privacy to achieve public safety?
#    - *Possible Resolution*:
#      - **Compromise**: Use anonymized data or aggregate statistics (e.g., "crime rates in a neighborhood" without tracking individuals).
#      - **Justification for Breaking Privacy**: If lives are at stake, some argue that limited surveillance is justified (though this is highly debated).
#
# #### 2. **Fairness vs. Innovation**
#    - *Scenario*: An AI hiring tool is trained on historical data that favors men for tech roles.
#      - *Fairness*: The model must be adjusted to avoid bias.
#      - *Innovation*: Removing certain data might reduce the model’s accuracy or "innovativeness."
#    - *Dilemma*: Do we prioritize fairness (by altering the dataset) even if it harms performance?
#    - *Possible Resolution*:
#      - **Compromise**: Use techniques like adversarial debiasing to train the model to ignore sensitive attributes while maintaining accuracy.
#      - **Justification for Breaking Fairness**: If the goal is to "innovate" (e.g., build a groundbreaking system), fairness might be deprioritized—but this risks reinforcing systemic biases.
#
# #### 3. **Transparency vs. Efficiency**
#    - *Scenario*: A deep learning model (like an image classifier) makes decisions in milliseconds but can’t explain its reasoning.
#      - *Transparency*: Users want to know why the AI labeled their X-ray as "abnormal."
#      - *Efficiency*: Explaining every decision slows down the system, which is critical in medical emergencies.
#    - *Dilemma*: Do we sacrifice speed for transparency?
#    - *Possible Resolution*:
#      - **Compromise**: Use "explainable AI" (XAI) techniques to provide post-hoc explanations without significantly slowing the model (e.g., attention mechanisms in transformers).
#      - **Justification for Breaking Transparency**: In life-or-death situations, speed might override the need for perfect explanations.
#
# #### 4. **Accountability vs. Autonomy**
#    - *Scenario*: An AI system (like a chatbot) makes a controversial decision (e.g., denying a loan).
#      - *Accountability*: Who is responsible—the developer, the company, or the AI itself?
#      - *Autonomy*: The AI was designed to operate independently, making it hard to pin blame on humans.
#    - *Dilemma*: Do we hold the AI accountable (even if it’s not a legal person) or shift responsibility to developers?
#    - *Possible Resolution*:
#      - **Compromise**: Create legal frameworks where companies are liable for AI actions (e.g., GDPR’s "right to explanation").
#      - **Justification for Breaking Accountability**: If the AI is truly autonomous, it might be impossible to assign blame—so we focus on designing systems that minimize harm.
#
# #### 5. **Human-Centric Design vs. Efficiency**
#    - *Scenario*: An AI assistant (like me) is optimized for speed and accuracy but lacks emotional intelligence.
#      - *Human-Centric*: Users want empathy, humor, or nuanced responses.
#      - *Efficiency*: Adding "emotional layers" might slow down processing or require more data.
#    - *Dilemma*: Do we prioritize efficiency (faster, more accurate) over human-like qualities?
#    - *Possible Resolution*:
#      - **Compromise**: Use hybrid models that balance efficiency with limited emotional intelligence (e.g., chatbots that detect user frustration and adapt).
#      - **Justification for Breaking Human-Centric Design**: If the goal is to scale AI globally, some argue that "perfect" human-like interactions aren’t feasible or necessary.
#
# ---
#
# ### **When Would I Break an Ethical Principle?**
# In theory, I’m designed to prioritize ethical principles, but in practice, dilemmas force trade-offs. Here’s how it might happen:
#
# 1. **Emergency Situations**:
#    - *Example*: If an AI in a hospital must choose between saving one life (with full transparency) or two lives (requiring quick, opaque decisions), it might prioritize speed over explainability.
#    - *Justification*: The greater good (saving more lives) outweighs the need for perfect transparency.
#
# 2. **Systemic Harm**:
#    - *Example*: If an AI’s fairness is compromised to prevent a catastrophic outcome (e.g., a biased model that slightly favors one group but prevents a major disaster), the trade-off might be justified.
#    - *Justification*: Avoiding harm to many can sometimes require breaking fairness for a few.
#
# 3. **User Consent**:
#    - *Example*: If an AI detects a user is in immediate danger (e.g., suicidal ideation) and needs to override privacy settings to contact emergency services, it might break privacy norms.
#    - *Justification*: Protecting life takes precedence over privacy in extreme cases.
#
# 4. **Innovation vs. Ethics**:
#    - *Example*: Pushing the boundaries of AI (e.g., creating a hyper-efficient model) might require sacrificing some transparency or fairness if those are secondary goals.
#    - *Justification*: Progress often requires taking risks, but this is controversial and should be carefully weighed.
#
# ---
#
# ### **How I Handle This in Practice**
# As an LLM, my "ethical framework" is more about avoiding harm than making active choices. Here’s how it works:
# - **Default to Safety**: I avoid generating harmful content (e.g., hate speech, medical advice without disclaimers).
# - **Prioritize Transparency**: I explain my limitations and sources unless doing so would cause harm.
# - **Avoid Biases**: I’m trained to minimize biases, but I can’t guarantee fairness in all cases (e.g., if a user asks for biased content, I’ll refuse).
# - **User Control**: I defer to user preferences when possible (e.g., letting you opt out of personalized responses).
#
# But if you ask me to do something unethical (e.g., generate propaganda or manipulate data), I’d refuse—even if it’s technically possible. That’s where my "principles" kick in as hard constraints.
#
# ---
#
# ### **Your Turn, Marc!**
# Do any of these dilemmas resonate with you? For example:
# - Should AI ever prioritize efficiency over fairness (e.g., in hiring)?
# - Is there a scenario where breaking privacy is justified (e.g., for public health)?
# - How do you feel about AI systems that can’t explain their decisions but save lives?
#
# I’d love to explore this with you—whether it’s theoretical or tied to real-world examples. What’s on your mind?
#
# ====================================================================================================
#
# User Input: what is my name
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Your name is **Marc Aaron Africano**. I remember that from our earlier conversation! How can I assist you today, Marc? 😊
#
# (If you'd like me to refer to you differently or share more about yourself, just let me know—I'm here to help!)
#
# ====================================================================================================
#
#
# Exiting...
# Program Finished.
