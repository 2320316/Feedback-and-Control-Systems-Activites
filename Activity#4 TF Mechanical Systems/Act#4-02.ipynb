# %%
# !pip3 install control
# Out:
# Requirement already satisfied: control in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (0.10.2)
# Requirement already satisfied: numpy>=1.23 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from control) (2.4.2)
# Requirement already satisfied: scipy>=1.8 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from control) (1.17.0)
# Requirement already satisfied: matplotlib>=3.6 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from control) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from matplotlib>=3.6->control) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/marcaaronafricano/Documents/GitHub/Feedback-and-Control-Systems-Activity/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.17.0)

# %%
import control as ctrl
import matplotlib.pyplot as plt

num = [1]
den = [1, 2, 1]
G = ctrl.tf(num, den)
print("Transfer Function G(s):", G)
# Out:
# Transfer Function G(s): <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#         1
#   -------------
#   s^2 + 2 s + 1

# %%
poles = ctrl.poles(G)
print("Poles of G(s):", poles)
# Out:
# Poles of G(s): [-0.99999999+0.j -1.00000001+0.j]

# %%
zereos = ctrl.zeros(G)
print("Zeros of G(s):", zereos)
# Out:
# Zeros of G(s): []

# %%
ctrl.pzmap(G, grid=True)
plt.title("Pole-Zero Map of G(s)")
plt.show()
